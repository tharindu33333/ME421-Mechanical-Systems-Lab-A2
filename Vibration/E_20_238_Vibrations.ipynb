# %% [markdown]
# <a href="https://colab.research.google.com/github/tharindu33333/ME421-Mechanical-Systems-Lab-A2/blob/main/Vibration/E_20_238_Vibrations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vibrations_E20_238

# %% [markdown]
# TecQuipment - Vibration Analyser

# %% [markdown]
# Consider the TecQuipment vibration analyser setup where one end of a rigid beam is pinned and the other end is connected to the frame through a spring while an unbalnced motor is attached to the middle section of the beam.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Week #1

# %% [markdown]
# # Activity #1
# Derive the 2-dof freedom model that will capture the first two dominant modes of small amplitude vibration of the system.

# %% [markdown]
# # 2-DOF Mechanical System Modeling
#
#
# ### Step 1: Forces Acting on Each Mass
#
# **Mass $M_1$**
# Forces acting on $M_1$:
# * Spring force from ground: $K_1 x_1(t)$
# * Damping force from ground: $C_1 \dot{x}_1(t)$
# * Interaction spring force: $K_2(x_1 - x_2)$
# * Interaction damping force: $C_2(\dot{x}_1 - \dot{x}_2)$
# * External force: $f_1(t)$
#
# Applying Newton’s Second Law:
# $$M_1 \ddot{x}_1 + C_1 \dot{x}_1 + K_1 x_1 + C_2(\dot{x}_1 - \dot{x}_2) + K_2(x_1 - x_2) = f_1(t)$$
#
# ---
#
# **Mass $M_2$**
# Forces acting on $M_2$:
# * Interaction spring force: $K_2(x_2 - x_1)$
# * Interaction damping force: $C_2(\dot{x}_2 - \dot{x}_1)$
# * External force: $f_2(t)$
#
# Applying Newton’s Second Law:
# $$M_2 \ddot{x}_2 + C_2(\dot{x}_2 - \dot{x}_1) + K_2(x_2 - x_1) = f_2(t)$$
#
# ---
#
# ### Step 2: Matrix Form of the 2-DOF Model
#
# The system can be written in the standard matrix form $[M]\{\ddot{x}\} + [C]\{\dot{x}\} + [K]\{x\} = \{F(t)\}$:
#
# $$\begin{bmatrix} M_1 & 0 \\ 0 & M_2 \end{bmatrix} \begin{bmatrix} \ddot{x}_1 \\ \ddot{x}_2 \end{bmatrix} + \begin{bmatrix} C_1 + C_2 & -C_2 \\ -C_2 & C_2 \end{bmatrix} \begin{bmatrix} \dot{x}_1 \\ \dot{x}_2 \end{bmatrix} + \begin{bmatrix} K_1 + K_2 & -K_2 \\ -K_2 & K_2 \end{bmatrix} \begin{bmatrix} x_1 \\ x_2 \end{bmatrix} = \begin{bmatrix} f_1(t) \\ f_2(t) \end{bmatrix}$$
#
# ---
#
# ### Final Statement
# The above equations form a 2-degree-of-freedom linear vibration model that captures the first two dominant modes of small-amplitude vibration of the system.
#
# ### Notes for Exams / Reports
# * If **free vibration** is required, set $f_1(t) = f_2(t) = 0$.
# * If **undamped**, set $C_1 = C_2 = 0$.
# * **Modal analysis** is obtained from the characteristic equation:
# $$\det(\mathbf{K} - \omega^2 \mathbf{M}) = 0$$

# %% [markdown]
# Plot the following:
#
# the unforced repsonse to an initiail diplacement of the spring end of the beam
# the forced response for three choices of the rotational speed of the motor
# theoretical frequency response of the system that captures the first two dominant modes of vibration of the system.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-01-07 150204.png](data:image/png;base64,...)

# %% [markdown]
# # Week #2

# %% [markdown]
# # Activity #4
#
# Plot the experimental frequency response of the system near resonance conditions and find $\omega_d$ and $x_{ss_{max}}$ and compare it with your theoretical estimates and discuss the reasons for discrepancies if any.
